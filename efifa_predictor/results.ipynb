# %% [markdown]
# #### Resultado testes - Base Numérica
#
# RandomForest:
# - R²:60.88%
# - RSME:1.50
#
# LinearRegression:
# - R²:2.33%
# - RSME:2.37
#
# ExtraTrees:
# - R²:67.94%
# - RSME:1.36
#
# ##### Colunas utilizadas
#
# - id_player_casa
# - gols_casa
# - id_time_casa
# - id_player_fora
# - gols_fora
# - id_time_fora
# - gols_total
# - id_resultado
#
# #### Melhor modelo
# Extra Trees - R2 maior e RSME menor

# %% [markdown]
# #### Model training gols total
# Features categóricas - sem métricas históricas
#
# RandomForest
# - R²:63.91%
# - RSME:1.44
#
# LinearRegression:
# - R²:1.17%
# - RSME:2.38
#
# ExtraTrees
# - R²:71.55%
# - RSME:1.28
